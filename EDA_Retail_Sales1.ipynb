# %% [markdown]
# OASIS INFOBYTE INTERNSHIP

# %% [markdown]
# LEVEL-1:- TASK 1
#
# Project Name - Exploratory Data Analysis(EDA) on Retail Sales Data
#
# Intern - Swathi Bonagiri
#
# Domain - Data Analytics

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/swath/Downloads/Retail_Sales_1/menu.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
print("Dataset Shape:", df.shape)
df.info()
print(df.isnull().sum())
print("Duplicate Rows:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# Dataset Shape: (260, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
plt.style.use("dark_background")
plt.figure(figsize=(8,6))
sns.histplot(df['Calories'], kde=True, color='skyblue')
plt.title('Calories Distribution of Menu Items')
plt.xlabel('Calories')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use("dark_background")
plt.figure(figsize=(10,6))
sns.countplot(x='Category', data=df, hue='Category', palette='viridis', legend=False)
plt.title('Count of Items in Each Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Calories', y='Item', data=top_calorie, hue='Item', palette='magma', legend=False)
plt.title('Top 10 High Calorie Items')
plt.xlabel('Calories')
plt.ylabel('Item')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Category', y='Calories', data=df, hue='Category', palette='coolwarm', legend=False)
plt.title('Calories Distribution Across Categories')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# %%
print("Insights:")

print("- Burgers, Chicken, and Sandwiches have more Calories and Fat.")
print("- Beverages like Shakes have high Calories and Sugar but low Protein.")
print("- Salads and Breakfast items have less Calories — good for healthy eating.")
print("- Sodium (Salt) is very high in Sides, Chicken, and Burgers.")
print("- Items with more Calories also have more Fat and Sodium.")
print("- Protein is high in Chicken, Beef, and Burger items.")
print("- Sides and Beverages have high Calories but low nutrition (less Protein).")

print("\nRecommendations:")

print("- Promote healthy items like Salads, Fruits, and Breakfast items in the menu.")
print("- Add a separate section for 'Low-Calorie' or 'Healthy Options'.")
print("- Reduce Salt and Fat in high-calorie items like Burgers and Sides.")
print("- Give customers an option to choose low-fat or low-salt items.")
print("- Show nutrition details in the menu for customer awareness.")
print("- Offer combo packs with healthy items to attract fitness customers.")
# Out:
# Insights:
# - Burgers, Chicken, and Sandwiches have more Calories and Fat.
# - Beverages like Shakes have high Calories and Sugar but low Protein.
# - Salads and Breakfast items have less Calories — good for healthy eating.
# - Sodium (Salt) is very high in Sides, Chicken, and Burgers.
# - Items with more Calories also have more Fat and Sodium.
# - Protein is high in Chicken, Beef, and Burger items.
# - Sides and Beverages have high Calories but low nutrition (less Protein).
#
# Recommendations:
# - Promote healthy items like Salads, Fruits, and Breakfast items in the menu.
# - Add a separate section for 'Low-Calorie' or 'Healthy Options'.
# - Reduce Salt and Fat in high-calorie items like Burgers and Sides.
# - Give customers an option to choose low-fat or low-salt items.
# - Show nutrition details in the menu for customer awareness.
# - Offer combo packs with healthy items to attract fitness customers.
